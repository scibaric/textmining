# %%
import nltk
from nltk import FreqDist


#nltk.download()

with open('theguardian.txt', 'r', encoding = "UTF-8") as file:
    data = file.read()

# %% [markdown]
# ### Tokeniziranje teksta

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(data)
print("Broj tokena: ", len(tokens))
print("Tokenizirani tekst\n")
print(tokens)
# Out:
# Broj tokena:  1815
# Tokenizirani tekst
#
# ['Have', 'Barcelona', 'found', 'the', 'next', 'Lionel', 'Messi', 'in', 'Alen', 'Halilovic', '?', 'Last', 'week', ',', 'Barcelona', 'finally', 'won', 'the', 'race', 'the', 'sign', 'the', '17-year-old', 'Croat', 'prodigy', ',', 'but', 'is', 'he', 'the', 'next', 'Lionel', 'Messi', '?', 'Or', 'the', 'next', 'Luka', 'Modric', '?', 'Or', 'neither', '?', 'Alen', 'Halilovic', 'will', 'turn', '18', 'in', 'June', 'and', 'yet', ',', 'for', 'many', 'in', 'his', 'country', ',', 'it', 'seems', 'as', 'if', 'he', 'has', 'been', 'around', 'for', 'ages', '.', 'Last', 'week', ',', 'when', 'Barcelona', 'finally', 'confirmed', 'that', 'the', 'young', 'Dinamo', 'Zagreb', 'prodigy', 'will', 'join', 'them', 'in', 'the', 'summer', ',', 'one', 'of', 'the', 'sentiments', 'back', 'in', 'Croatia', 'was', 'relief', '.', 'That', 'was', 'not', 'because', 'people', 'there', 'do', 'not', 'rate', 'the', '17-year-old', ',', 'who', 'had', 'been', 'linked', 'with', 'just', 'about', 'every', 'major', 'European', 'club', ',', 'and', 'were', 'only', 'too', 'happy', 'to', 'see', 'the', 'back', 'of', 'him', '.', 'As', 'almost', 'anyone', 'who', 'has', 'seen', 'him', 'play', 'will', 'testify', ',', 'Halilovic', 'really', 'has', 'that', 'something', 'special', 'about', 'him', 'and', 'could', 'become', 'one', 'of', 'the', 'best', 'players', 'in', 'the', 'world', 'in', 'the', 'coming', 'years', '.', 'No', ',', 'it', 'was', 'just', 'that', 'the', 'matter', 'of', 'his', 'leaving', 'had', 'become', 'a', 'saga', '.', 'It', 'was', 'always', 'clear', 'that', 'he', 'would', 'leave', 'Dinamo', 'before', 'making', 'his', 'true', 'mark', 'on', 'the', 'pitch', 'for', 'the', 'club', '.', 'In', 'fact', ',', 'the', 'rumours', 'about', 'Halilovic', 'started', 'when', 'he', 'was', '14', 'or', '15', '.', 'The', 'club', "'s", 'chief', 'executive', ',', 'Zdravko', 'Mamic', ',', 'claims', 'he', 'personally', '``', 'took', 'him', 'off', 'the', 'truck', 'heading', 'to', 'Madrid', "''", ',', 'where', 'the', 'player', "'s", 'father', 'Sejad', ',', 'the', 'former', 'Bosnia', 'and', 'Herzegovina', 'international', ',', '``', 'had', 'everything', 'agreed', 'with', 'Atlético', 'and', 'they', 'were', 'moving', 'to', 'their', 'new', 'home', 'there', '...', 'but', 'I', 'stopped', 'the', 'family', 'in', 'front', 'of', 'the', 'customs', 'office', 'at', 'the', 'Croatian', 'border', 'and', 'talked', 'them', 'into', 'returning', "''", '.', 'Dinamo', ',', 'of', 'course', ',', 'used', 'every', 'opportunity', 'they', 'could', 'get', 'to', 'fuel', 'the', "'Halilovic", 'Hype', "'", ',', 'as', 'selling', 'their', 'most', 'promising', 'players', 'for', 'big', 'money', 'is', 'what', 'they', 'do', 'best', 'these', 'days', '.', 'Last', 'year', 'the', 'midfielder', 'Mateo', 'Kovacic', 'was', '18', 'when', 'he', 'joined', 'Internazionale', 'for', '€11m', ';', 'the', 'defender', 'Tin', 'Jedvaj', 'was', 'even', 'younger', 'than', 'Halilovic', 'is', 'now', 'when', 'Roma', 'signed', 'him', 'for', '€5m', '.', '``', 'I', "'m", 'fully', 'aware', 'of', 'how', 'pretentious', 'this', 'may', 'sound', ',', "''", 'Dinamo', "'s", 'director', 'of', 'football', ',', 'Zoran', 'Mamic', ',', 'who', 'is', 'now', 'also', 'their', 'head', 'coach', '(', 'and', ',', 'incidentally', ',', 'the', 'brother', 'of', 'the', 'club', "'s", 'controversial', 'executive', 'director', 'Zdravko', ')', ',', 'told', 'the', 'Spanish', 'Canal+', 'in', '2012', '.', '``', 'But', 'he', "'s", 'a', 'Messi-type', 'player', 'if', 'there', 'ever', 'was', 'one', '.', "''", 'Part', 'of', 'the', 'problem', 'is', 'that', 'Halilovic', 'has', 'arguably', 'been', 'pushed', 'too', 'hard', 'and', 'too', 'early', ',', 'already', 'playing', 'for', 'the', 'senior', 'squad', 'at', '16', 'and', 'becoming', 'the', 'second-youngest', 'player', 'ever', 'to', 'appear', 'in', 'the', 'Champions', 'League', '(', 'after', 'Anderlecht', "'s", 'Celestine', 'Babayaro', 'in', '1994', ')', '.', 'In', 'June', 'last', 'year', 'he', 'even', 'made', 'his', 'full', 'international', 'debut', 'for', 'C ...

# %% [markdown]
# ### Tokeniziranje teksta na nacin da vrati samo rijeci bez interpunkcijskih znakova

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(data)
print("Broj tokena: ", len(tokens))
print("Tokenizirani tekst bez interpunkcijskih znakova\n")
print(tokens)
# Out:
# Broj tokena:  1648
# Tokenizirani tekst bez interpunkcijskih znakova
#
# ['Have', 'Barcelona', 'found', 'the', 'next', 'Lionel', 'Messi', 'in', 'Alen', 'Halilovic', 'Last', 'week', 'Barcelona', 'finally', 'won', 'the', 'race', 'the', 'sign', 'the', '17', 'year', 'old', 'Croat', 'prodigy', 'but', 'is', 'he', 'the', 'next', 'Lionel', 'Messi', 'Or', 'the', 'next', 'Luka', 'Modric', 'Or', 'neither', 'Alen', 'Halilovic', 'will', 'turn', '18', 'in', 'June', 'and', 'yet', 'for', 'many', 'in', 'his', 'country', 'it', 'seems', 'as', 'if', 'he', 'has', 'been', 'around', 'for', 'ages', 'Last', 'week', 'when', 'Barcelona', 'finally', 'confirmed', 'that', 'the', 'young', 'Dinamo', 'Zagreb', 'prodigy', 'will', 'join', 'them', 'in', 'the', 'summer', 'one', 'of', 'the', 'sentiments', 'back', 'in', 'Croatia', 'was', 'relief', 'That', 'was', 'not', 'because', 'people', 'there', 'do', 'not', 'rate', 'the', '17', 'year', 'old', 'who', 'had', 'been', 'linked', 'with', 'just', 'about', 'every', 'major', 'European', 'club', 'and', 'were', 'only', 'too', 'happy', 'to', 'see', 'the', 'back', 'of', 'him', 'As', 'almost', 'anyone', 'who', 'has', 'seen', 'him', 'play', 'will', 'testify', 'Halilovic', 'really', 'has', 'that', 'something', 'special', 'about', 'him', 'and', 'could', 'become', 'one', 'of', 'the', 'best', 'players', 'in', 'the', 'world', 'in', 'the', 'coming', 'years', 'No', 'it', 'was', 'just', 'that', 'the', 'matter', 'of', 'his', 'leaving', 'had', 'become', 'a', 'saga', 'It', 'was', 'always', 'clear', 'that', 'he', 'would', 'leave', 'Dinamo', 'before', 'making', 'his', 'true', 'mark', 'on', 'the', 'pitch', 'for', 'the', 'club', 'In', 'fact', 'the', 'rumours', 'about', 'Halilovic', 'started', 'when', 'he', 'was', '14', 'or', '15', 'The', 'club', 's', 'chief', 'executive', 'Zdravko', 'Mamic', 'claims', 'he', 'personally', 'took', 'him', 'off', 'the', 'truck', 'heading', 'to', 'Madrid', 'where', 'the', 'player', 's', 'father', 'Sejad', 'the', 'former', 'Bosnia', 'and', 'Herzegovina', 'international', 'had', 'everything', 'agreed', 'with', 'Atlético', 'and', 'they', 'were', 'moving', 'to', 'their', 'new', 'home', 'there', 'but', 'I', 'stopped', 'the', 'family', 'in', 'front', 'of', 'the', 'customs', 'office', 'at', 'the', 'Croatian', 'border', 'and', 'talked', 'them', 'into', 'returning', 'Dinamo', 'of', 'course', 'used', 'every', 'opportunity', 'they', 'could', 'get', 'to', 'fuel', 'the', 'Halilovic', 'Hype', 'as', 'selling', 'their', 'most', 'promising', 'players', 'for', 'big', 'money', 'is', 'what', 'they', 'do', 'best', 'these', 'days', 'Last', 'year', 'the', 'midfielder', 'Mateo', 'Kovacic', 'was', '18', 'when', 'he', 'joined', 'Internazionale', 'for', '11m', 'the', 'defender', 'Tin', 'Jedvaj', 'was', 'even', 'younger', 'than', 'Halilovic', 'is', 'now', 'when', 'Roma', 'signed', 'him', 'for', '5m', 'I', 'm', 'fully', 'aware', 'of', 'how', 'pretentious', 'this', 'may', 'sound', 'Dinamo', 's', 'director', 'of', 'football', 'Zoran', 'Mamic', 'who', 'is', 'now', 'also', 'their', 'head', 'coach', 'and', 'incidentally', 'the', 'brother', 'of', 'the', 'club', 's', 'controversial', 'executive', 'director', 'Zdravko', 'told', 'the', 'Spanish', 'Canal', 'in', '2012', 'But', 'he', 's', 'a', 'Messi', 'type', 'player', 'if', 'there', 'ever', 'was', 'one', 'Part', 'of', 'the', 'problem', 'is', 'that', 'Halilovic', 'has', 'arguably', 'been', 'pushed', 'too', 'hard', 'and', 'too', 'early', 'already', 'playing', 'for', 'the', 'senior', 'squad', 'at', '16', 'and', 'becoming', 'the', 'second', 'youngest', 'player', 'ever', 'to', 'appear', 'in', 'the', 'Champions', 'League', 'after', 'Anderlecht', 's', 'Celestine', 'Babayaro', 'in', '1994', 'In', 'June', 'last', 'year', 'he', 'even', 'made', 'his', 'full', 'international', 'debut', 'for', 'Croatia', 'in', 'a', 'friendly', 'against', 'Portugal', 'he', 'was', 'not', 'even', 'a', 'starter', 'for', 'Dinamo', 'back', 'then', 'He', 'is', 'still', 'not', 'expected', 'to', 'make', 'Croatia', 's', 'World', 'Cup', 'squad', 'And', 'then', 'there', 'were', 'the', 'attempts', 'to', 'lure', ' ...

# %% [markdown]
# ### Rijeci s velikim slovima pretvaramo u mala slova kako bi mogli lakse maknuti stop wordove

# %%
from collections import Counter
from nltk.corpus import stopwords

tokens = [word.lower() for word in tokens]
fresh_tokens = list(tokens)

# %% [markdown]
# ### Stematizacija - PorterStemmer

# %%
from nltk.stem.porter import PorterStemmer

porter_stemmer = PorterStemmer()
stemmed_tokens = []

for word in tokens:
    stemmed_tokens.append(porter_stemmer.stem(word))

print("Stematizirani tekst")
print(stemmed_tokens)
# Out:
# Stematizirani tekst
# ['have', 'barcelona', 'found', 'the', 'next', 'lionel', 'messi', 'in', 'alen', 'halilov', 'last', 'week', 'barcelona', 'final', 'won', 'the', 'race', 'the', 'sign', 'the', '17', 'year', 'old', 'croat', 'prodigi', 'but', 'is', 'he', 'the', 'next', 'lionel', 'messi', 'or', 'the', 'next', 'luka', 'modric', 'or', 'neither', 'alen', 'halilov', 'will', 'turn', '18', 'in', 'june', 'and', 'yet', 'for', 'mani', 'in', 'hi', 'countri', 'it', 'seem', 'as', 'if', 'he', 'ha', 'been', 'around', 'for', 'age', 'last', 'week', 'when', 'barcelona', 'final', 'confirm', 'that', 'the', 'young', 'dinamo', 'zagreb', 'prodigi', 'will', 'join', 'them', 'in', 'the', 'summer', 'one', 'of', 'the', 'sentiment', 'back', 'in', 'croatia', 'wa', 'relief', 'that', 'wa', 'not', 'becaus', 'peopl', 'there', 'do', 'not', 'rate', 'the', '17', 'year', 'old', 'who', 'had', 'been', 'link', 'with', 'just', 'about', 'everi', 'major', 'european', 'club', 'and', 'were', 'onli', 'too', 'happi', 'to', 'see', 'the', 'back', 'of', 'him', 'as', 'almost', 'anyon', 'who', 'ha', 'seen', 'him', 'play', 'will', 'testifi', 'halilov', 'realli', 'ha', 'that', 'someth', 'special', 'about', 'him', 'and', 'could', 'becom', 'one', 'of', 'the', 'best', 'player', 'in', 'the', 'world', 'in', 'the', 'come', 'year', 'no', 'it', 'wa', 'just', 'that', 'the', 'matter', 'of', 'hi', 'leav', 'had', 'becom', 'a', 'saga', 'it', 'wa', 'alway', 'clear', 'that', 'he', 'would', 'leav', 'dinamo', 'befor', 'make', 'hi', 'true', 'mark', 'on', 'the', 'pitch', 'for', 'the', 'club', 'in', 'fact', 'the', 'rumour', 'about', 'halilov', 'start', 'when', 'he', 'wa', '14', 'or', '15', 'the', 'club', 's', 'chief', 'execut', 'zdravko', 'mamic', 'claim', 'he', 'person', 'took', 'him', 'off', 'the', 'truck', 'head', 'to', 'madrid', 'where', 'the', 'player', 's', 'father', 'sejad', 'the', 'former', 'bosnia', 'and', 'herzegovina', 'intern', 'had', 'everyth', 'agre', 'with', 'atlético', 'and', 'they', 'were', 'move', 'to', 'their', 'new', 'home', 'there', 'but', 'i', 'stop', 'the', 'famili', 'in', 'front', 'of', 'the', 'custom', 'offic', 'at', 'the', 'croatian', 'border', 'and', 'talk', 'them', 'into', 'return', 'dinamo', 'of', 'cours', 'use', 'everi', 'opportun', 'they', 'could', 'get', 'to', 'fuel', 'the', 'halilov', 'hype', 'as', 'sell', 'their', 'most', 'promis', 'player', 'for', 'big', 'money', 'is', 'what', 'they', 'do', 'best', 'these', 'day', 'last', 'year', 'the', 'midfield', 'mateo', 'kovac', 'wa', '18', 'when', 'he', 'join', 'internazional', 'for', '11m', 'the', 'defend', 'tin', 'jedvaj', 'wa', 'even', 'younger', 'than', 'halilov', 'is', 'now', 'when', 'roma', 'sign', 'him', 'for', '5m', 'i', 'm', 'fulli', 'awar', 'of', 'how', 'pretenti', 'thi', 'may', 'sound', 'dinamo', 's', 'director', 'of', 'footbal', 'zoran', 'mamic', 'who', 'is', 'now', 'also', 'their', 'head', 'coach', 'and', 'incident', 'the', 'brother', 'of', 'the', 'club', 's', 'controversi', 'execut', 'director', 'zdravko', 'told', 'the', 'spanish', 'canal', 'in', '2012', 'but', 'he', 's', 'a', 'messi', 'type', 'player', 'if', 'there', 'ever', 'wa', 'one', 'part', 'of', 'the', 'problem', 'is', 'that', 'halilov', 'ha', 'arguabl', 'been', 'push', 'too', 'hard', 'and', 'too', 'earli', 'alreadi', 'play', 'for', 'the', 'senior', 'squad', 'at', '16', 'and', 'becom', 'the', 'second', 'youngest', 'player', 'ever', 'to', 'appear', 'in', 'the', 'champion', 'leagu', 'after', 'anderlecht', 's', 'celestin', 'babayaro', 'in', '1994', 'in', 'june', 'last', 'year', 'he', 'even', 'made', 'hi', 'full', 'intern', 'debut', 'for', 'croatia', 'in', 'a', 'friendli', 'against', 'portug', 'he', 'wa', 'not', 'even', 'a', 'starter', 'for', 'dinamo', 'back', 'then', 'he', 'is', 'still', 'not', 'expect', 'to', 'make', 'croatia', 's', 'world', 'cup', 'squad', 'and', 'then', 'there', 'were', 'the', 'attempt', 'to', 'lure', 'him', 'to', 'london', 'by', 'tottenham', 'hotspur', 'and', 'reportedli', 'arsen', 'last', 'summer', 'that', 'allegedli', 'collaps', 'becaus', 'halilov', 's', 'fath ...

# %% [markdown]
# ### Lematizacija

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = []

for word in stemmed_tokens:
    lemmatized_tokens.append(lemmatizer.lemmatize(word))

print("Lematizirani tekst")
print(lemmatized_tokens)
# Out:
# Lematizirani tekst
# ['have', 'barcelona', 'found', 'the', 'next', 'lionel', 'messi', 'in', 'alen', 'halilov', 'last', 'week', 'barcelona', 'final', 'won', 'the', 'race', 'the', 'sign', 'the', '17', 'year', 'old', 'croat', 'prodigi', 'but', 'is', 'he', 'the', 'next', 'lionel', 'messi', 'or', 'the', 'next', 'luka', 'modric', 'or', 'neither', 'alen', 'halilov', 'will', 'turn', '18', 'in', 'june', 'and', 'yet', 'for', 'mani', 'in', 'hi', 'countri', 'it', 'seem', 'a', 'if', 'he', 'ha', 'been', 'around', 'for', 'age', 'last', 'week', 'when', 'barcelona', 'final', 'confirm', 'that', 'the', 'young', 'dinamo', 'zagreb', 'prodigi', 'will', 'join', 'them', 'in', 'the', 'summer', 'one', 'of', 'the', 'sentiment', 'back', 'in', 'croatia', 'wa', 'relief', 'that', 'wa', 'not', 'becaus', 'peopl', 'there', 'do', 'not', 'rate', 'the', '17', 'year', 'old', 'who', 'had', 'been', 'link', 'with', 'just', 'about', 'everi', 'major', 'european', 'club', 'and', 'were', 'onli', 'too', 'happi', 'to', 'see', 'the', 'back', 'of', 'him', 'a', 'almost', 'anyon', 'who', 'ha', 'seen', 'him', 'play', 'will', 'testifi', 'halilov', 'realli', 'ha', 'that', 'someth', 'special', 'about', 'him', 'and', 'could', 'becom', 'one', 'of', 'the', 'best', 'player', 'in', 'the', 'world', 'in', 'the', 'come', 'year', 'no', 'it', 'wa', 'just', 'that', 'the', 'matter', 'of', 'hi', 'leav', 'had', 'becom', 'a', 'saga', 'it', 'wa', 'alway', 'clear', 'that', 'he', 'would', 'leav', 'dinamo', 'befor', 'make', 'hi', 'true', 'mark', 'on', 'the', 'pitch', 'for', 'the', 'club', 'in', 'fact', 'the', 'rumour', 'about', 'halilov', 'start', 'when', 'he', 'wa', '14', 'or', '15', 'the', 'club', 's', 'chief', 'execut', 'zdravko', 'mamic', 'claim', 'he', 'person', 'took', 'him', 'off', 'the', 'truck', 'head', 'to', 'madrid', 'where', 'the', 'player', 's', 'father', 'sejad', 'the', 'former', 'bosnia', 'and', 'herzegovina', 'intern', 'had', 'everyth', 'agre', 'with', 'atlético', 'and', 'they', 'were', 'move', 'to', 'their', 'new', 'home', 'there', 'but', 'i', 'stop', 'the', 'famili', 'in', 'front', 'of', 'the', 'custom', 'offic', 'at', 'the', 'croatian', 'border', 'and', 'talk', 'them', 'into', 'return', 'dinamo', 'of', 'cours', 'use', 'everi', 'opportun', 'they', 'could', 'get', 'to', 'fuel', 'the', 'halilov', 'hype', 'a', 'sell', 'their', 'most', 'promis', 'player', 'for', 'big', 'money', 'is', 'what', 'they', 'do', 'best', 'these', 'day', 'last', 'year', 'the', 'midfield', 'mateo', 'kovac', 'wa', '18', 'when', 'he', 'join', 'internazional', 'for', '11m', 'the', 'defend', 'tin', 'jedvaj', 'wa', 'even', 'younger', 'than', 'halilov', 'is', 'now', 'when', 'rom', 'sign', 'him', 'for', '5m', 'i', 'm', 'fulli', 'awar', 'of', 'how', 'pretenti', 'thi', 'may', 'sound', 'dinamo', 's', 'director', 'of', 'footbal', 'zoran', 'mamic', 'who', 'is', 'now', 'also', 'their', 'head', 'coach', 'and', 'incident', 'the', 'brother', 'of', 'the', 'club', 's', 'controversi', 'execut', 'director', 'zdravko', 'told', 'the', 'spanish', 'canal', 'in', '2012', 'but', 'he', 's', 'a', 'messi', 'type', 'player', 'if', 'there', 'ever', 'wa', 'one', 'part', 'of', 'the', 'problem', 'is', 'that', 'halilov', 'ha', 'arguabl', 'been', 'push', 'too', 'hard', 'and', 'too', 'earli', 'alreadi', 'play', 'for', 'the', 'senior', 'squad', 'at', '16', 'and', 'becom', 'the', 'second', 'youngest', 'player', 'ever', 'to', 'appear', 'in', 'the', 'champion', 'leagu', 'after', 'anderlecht', 's', 'celestin', 'babayaro', 'in', '1994', 'in', 'june', 'last', 'year', 'he', 'even', 'made', 'hi', 'full', 'intern', 'debut', 'for', 'croatia', 'in', 'a', 'friendli', 'against', 'portug', 'he', 'wa', 'not', 'even', 'a', 'starter', 'for', 'dinamo', 'back', 'then', 'he', 'is', 'still', 'not', 'expect', 'to', 'make', 'croatia', 's', 'world', 'cup', 'squad', 'and', 'then', 'there', 'were', 'the', 'attempt', 'to', 'lure', 'him', 'to', 'london', 'by', 'tottenham', 'hotspur', 'and', 'reportedli', 'arsen', 'last', 'summer', 'that', 'allegedli', 'collaps', 'becaus', 'halilov', 's', 'father', ...

# %% [markdown]
# ### Najfrekventije riječi

# %%
word_count = Counter(lemmatized_tokens)
print("Najfrekventnije riječi ", word_count.most_common(30))

fd = FreqDist(lemmatized_tokens)
fd.plot(30, title='30 najfrekventnijih riječi')
# Out:
# Najfrekventnije riječi  [('the', 111), ('to', 43), ('of', 33), ('and', 32), ('a', 32), ('in', 31), ('he', 29), ('that', 26), ('for', 24), ('is', 22), ('halilov', 21), ('wa', 21), ('s', 21), ('hi', 18), ('ha', 16), ('not', 16), ('club', 16), ('player', 14), ('have', 13), ('barcelona', 13), ('year', 13), ('will', 13), ('dinamo', 13), ('they', 11), ('but', 10), ('him', 10), ('been', 9), ('when', 9), ('be', 9), ('alen', 8)]

# %% [markdown]
# ### Najfrekventije riječi bez stop word-ova

# %%
from nltk.corpus import stopwords

nltk_stop_words = set(stopwords.words("english"))
tokens_without_stop_words = []

for word in lemmatized_tokens:
    if word not in nltk_stop_words:
        tokens_without_stop_words.append(word)

word_count_without_stop_words = Counter(tokens_without_stop_words)
print("Najfrekventnije riječi bez stop word-ova")
print(word_count_without_stop_words.most_common(30))
fd = FreqDist(word_count_without_stop_words)
fd.plot(30, title='30 najfrekventnijih riječi bez stop word-ova')
# Out:
# Najfrekventnije riječi bez stop word-ova
# [('halilov', 21), ('wa', 21), ('hi', 18), ('ha', 16), ('club', 16), ('player', 14), ('barcelona', 13), ('year', 13), ('dinamo', 13), ('alen', 8), ('one', 8), ('sign', 7), ('move', 7), ('transfer', 7), ('last', 6), ('old', 6), ('onli', 6), ('thi', 6), ('barça', 6), ('next', 5), ('messi', 5), ('becaus', 5), ('play', 5), ('defend', 5), ('even', 5), ('spanish', 5), ('ever', 5), ('ani', 5), ('go', 5), ('team', 5)]

# %% [markdown]
# ### Concordance 10 najčešćih riječi u tekstu

# %%
text = nltk.Text(tokens)

ten_most_common_words = word_count_without_stop_words.most_common(10)
print(ten_most_common_words)
for w in ten_most_common_words:
    text.concordance(w[0])
# Out:
# [('halilov', 21), ('wa', 21), ('hi', 18), ('ha', 16), ('club', 16), ('player', 14), ('barcelona', 13), ('year', 13), ('dinamo', 13), ('alen', 8)]
# no matches
# no matches
# no matches
# no matches
# Displaying 15 of 15 matches:
# with just about every major european club and were only too happy to see the b
# g his true mark on the pitch for the club in fact the rumours about halilovic
# vic started when he was 14 or 15 the club s chief executive zdravko mamic clai
#  and incidentally the brother of the club s controversial executive director z
# er experience before moving to a big club and felt alen was not yet ready he t
# s rejection of the move had cost the club 15m in the end dinamo got only 2 2m
# t was not dinamo s call any more the club have always had a policy of binding
# ould give something more back to the club that developed the player and that h
# yer and that he should not leave the club without proper compensation but the
#  sanctions taken against the spanish club barça have announced that they will
# t josep maria bartomeu said that his club were victims of a grave injustice ad
# ars and which is the essence of this club we are not prepared in any way to gi
# the rights of minors he defended the club s la masia academy saying hands off
#  and 101 days old which made him the club s youngest ever player he scored sev
# even goals in 44 appearances for the club the move was thought to be under thr
# Displaying 8 of 8 matches:
# e truck heading to madrid where the player s father sejad the former bosnia an
# canal in 2012 but he s a messi type player if there ever was one part of the p
# 16 and becoming the second youngest player ever to appear in the champions lea
# ign a long term deal in the end the player had a valid contract only until the
# back to the club that developed the player and that he should not leave the cl
#  the 17 year old and what kind of a player is he well he is not the next luka
# h more direct and attacking another player halilovic has been compared to is b
# h made him the club s youngest ever player he scored seven goals in 44 appeara
# Displaying 13 of 13 matches:
# have barcelona found the next lionel messi in ale
#  messi in alen halilovic last week barcelona finally won the race the sign the
# een around for ages last week when barcelona finally confirmed that the young d
#  father later revealed so what can barcelona and their fans expect from the 17
# great argentinian alen halilovic s barcelona move will go through despite trans
# f his client from dinamo zagreb to barcelona is in any danger despite the fifa
# but believes the sanctions against barcelona have gone too far fifa has done we
# and the correct social environment barcelona s president josep maria bartomeu s
# k that the sanction will be lifted barcelona confirm signing of croatia wonderk
# f croatia wonderkid alen halilovic barcelona have signed the highly rated teena
#  halilovic will initially join the barcelona s b team but is not expected to ha
# t to be under threat in april when barcelona were handed a two window transfer
# d pending an appeal the signing is barcelona s second significant transfer of t
# Displaying 9 of 9 matches:
# finally won the race the sign the 17 year old croat prodigy but is he the next
# ause people there do not rate the 17 year old who had been linked with just ab
# is what they do best these days last year the midfielder mateo kovacic was 18
# estine babayaro in 1994 in june last year he even made his full international
# na and their fans expect from the 17 year old and what kind of a player is he
# al after being hit on wednesday by a year long transfer ban for of contravenin
# in 1995 believes the deal for the 17 year old which was announced last week wi
# bts that if barça were to sign an 11 year old they would guarantee proper educ
# lilovic from dinamo zagreb on a five year contract the diminutive midfielder w
# Displaying 13 of 13 matches:
# na finally confirmed that the young dinamo zagreb prodigy will join them in th
# as always clear that he would leave dinamo before making his true mark on the
# rder and talked them into returning dinamo of course used every opportunity th
# e of how pretentious this may sound dinamo s director of football zoran mamic
# tugal he was not even a starter for dinamo back then he is still not expected
# s not yet ready he then claimed the dinamo executives had not talked to him fo
# ve had cost the club 15m in the end dinamo got only 2 2m from barça though the
# l came close to fruition it was not dinamo s call any more the club have alway
# th the path chosen by another young dinamo prospect robert muric who has been
# o is bayern s arjen robben and when dinamo mis use him on the right wing his e
# eve the transfer of his client from dinamo zagreb to barcelona is in any dange
#  rated teenager alen halilovic from dinamo zagreb on a five year contract the
# tryman luka modric since making his dinamo debut at 16 years and 101 days old
# Displaying 8 of 8 matches:
# elona found the next lionel messi in alen halilovic last week barcelona finall
# i or the next luka modric or neither alen halilovic will turn 18 in june and y
# before moving to a big club and felt alen was not yet ready he then claimed th
# understudy for the great argentinian alen halilovic s barcelona move will go t
# n the lawyer of the croatian prodigy alen halilovic does not believe the trans
# oresee for one second that my client alen halilovic will not be able to play f
# confirm signing of croatia wonderkid alen halilovic barcelona have signed the
# ave signed the highly rated teenager alen halilovic from dinamo zagreb on a fi

# %% [markdown]
# ### Kolokacije 10 najčešćih riječi

# %%
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder, TrigramAssocMeasures, TrigramCollocationFinder
bigram_measures = BigramAssocMeasures()
trigram_measures = TrigramAssocMeasures()

bigram_finder = BigramCollocationFinder.from_words(tokens)
bigram_finder.apply_freq_filter(2)
print("Bigrami")
print(bigram_finder.nbest(bigram_measures.likelihood_ratio, 10))
bigram_finder.apply_word_filter(lambda w: 'alen' in w or 'year' in w or 'dinamo' in w or 'rule' in w)
print("Bigrami s filterom")
print(bigram_finder.nbest(bigram_measures.likelihood_ratio, 10))


trigram_finder = TrigramCollocationFinder.from_words(tokens)
trigram_finder.apply_freq_filter(2)
print("Trigrami")
print(trigram_finder.nbest(trigram_measures.likelihood_ratio, 10))
trigram_finder.apply_word_filter(lambda w: 'alen' in w or 'year' in w or 'dinamo' in w or 'rule' in w)
print("Trigrami s filterom")
print(trigram_finder.nbest(trigram_measures.likelihood_ratio, 10))
# Out:
# Bigrami
# [('alen', 'halilovic'), ('year', 'old'), ('la', 'masia'), ('luka', 'modric'), ('17', 'year'), ('lionel', 'messi'), ('the', 'club'), ('has', 'been'), ('last', 'week'), ('much', 'more')]
# Bigrami s filterom
# [('la', 'masia'), ('luka', 'modric'), ('lionel', 'messi'), ('the', 'club'), ('has', 'been'), ('last', 'week'), ('much', 'more'), ('transfer', 'ban'), ('the', 'next'), ('at', '16')]
# Trigrami
# [('17', 'year', 'old'), ('alen', 'halilovic', 'will'), ('the', '17', 'year'), ('off', 'la', 'masia'), ('next', 'luka', 'modric'), ('has', 'been', 'compared'), ('the', 'club', 's'), ('next', 'lionel', 'messi'), ('hands', 'off', 'la'), ('he', 'has', 'been')]
# Trigrami s filterom
# [('off', 'la', 'masia'), ('next', 'luka', 'modric'), ('has', 'been', 'compared'), ('the', 'club', 's'), ('next', 'lionel', 'messi'), ('hands', 'off', 'la'), ('he', 'has', 'been'), ('for', 'the', 'club'), ('the', 'next', 'lionel'), ('the', 'next', 'luka')]

# %% [markdown]
# ### Leksicki diverzificitet i postotak najcesce rijeci u tekstu

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(count, total):
    return 100 * count / total

print('Leksicki diverzificitet ', lexical_diversity(lemmatized_tokens))
print('Postotak rijeci halilov u tekstu ', round(percentage(lemmatized_tokens.count('halilov'), len(lemmatized_tokens)), 2))
# Out:
# Leksicki diverzificitet  0.3470873786407767
# Postotak rijeci halilov u tekstu  1.27

# %% [markdown]
# ### Korpus teksta Brown

# %%
from nltk.corpus import brown

print('Brown kategorije:\n', brown.categories())
genres = brown.categories()
words = ['halilovic', 'club', 'barcelona', 'dinamo', 'barça', 'messi', 'spanish', 'fifa',  'croatia']
most_frequent_words_in_brown = {}
for genre in genres:
    genre_text = brown.words(categories = genre)
    fdist = nltk.FreqDist(genre_text)
    for w in words:
        if fdist[w] > 0:
            lst = []
            lst.append(w)
            lst.append(fdist[w])
            most_frequent_words_in_brown[genre] = lst

for key in most_frequent_words_in_brown:
    print(key, '->', most_frequent_words_in_brown[key])
# Out:
# Brown kategorije:
#  ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# adventure -> ['club', 1]
# belles_lettres -> ['club', 6]
# editorial -> ['club', 7]
# fiction -> ['club', 1]
# government -> ['club', 2]
# hobbies -> ['club', 3]
# humor -> ['club', 3]
# lore -> ['club', 4]
# mystery -> ['club', 1]
# news -> ['club', 29]
# religion -> ['club', 1]
# reviews -> ['club', 2]
# romance -> ['club', 9]

# %%
from nltk.corpus import reuters

print('Reuters kategorije:\n', reuters.categories())
genres = reuters.categories()
words = ['halilovic', 'club', 'barcelona', 'dinamo', 'barça', 'messi', 'spanish', 'fifa',  'croatia']
most_frequent_words_in_reuters = {}
for genre in genres:
    fdist = nltk.FreqDist(genre_text)
    for w in words:
        if fdist[w] > 0:
            lst = []
            lst.append(w)
            lst.append(fdist[w])
            most_frequent_words_in_reuters[genre] = lst

for key in most_frequent_words_in_reuters:
    print(key, '->', most_frequent_words_in_reuters[key])
# Out:
# Reuters kategorije:
#  ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee', 'copper', 'copra-cake', 'corn', 'cotton', 'cotton-oil', 'cpi', 'cpu', 'crude', 'dfl', 'dlr', 'dmk', 'earn', 'fuel', 'gas', 'gnp', 'gold', 'grain', 'groundnut', 'groundnut-oil', 'heat', 'hog', 'housing', 'income', 'instal-debt', 'interest', 'ipi', 'iron-steel', 'jet', 'jobs', 'l-cattle', 'lead', 'lei', 'lin-oil', 'livestock', 'lumber', 'meal-feed', 'money-fx', 'money-supply', 'naphtha', 'nat-gas', 'nickel', 'nkr', 'nzdlr', 'oat', 'oilseed', 'orange', 'palladium', 'palm-oil', 'palmkernel', 'pet-chem', 'platinum', 'potato', 'propane', 'rand', 'rape-oil', 'rapeseed', 'reserves', 'retail', 'rice', 'rubber', 'rye', 'ship', 'silver', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'strategic-metal', 'sugar', 'sun-meal', 'sun-oil', 'sunseed', 'tea', 'tin', 'trade', 'veg-oil', 'wheat', 'wpi', 'yen', 'zinc']
# acq -> ['club', 10]
# corn -> ['spanish', 1]
# earn -> ['club', 8]
# grain -> ['spanish', 1]
# interest -> ['club', 1]
# oilseed -> ['spanish', 1]
# palm-oil -> ['spanish', 1]
# rapeseed -> ['spanish', 1]
# ship -> ['spanish', 1]
# soy-oil -> ['spanish', 1]
# trade -> ['club', 1]
# wheat -> ['spanish', 1]

# %% [markdown]
# ### Lingvističko stablo

# %%
sentence = 'Barcelona have signed the highly-rated teenager Alen Halilovic from Dinamo Zagreb on a five-year contract'

# %%
grammar_np = r"NP: {<DT>?<JJ>?<NN>}" 
chunk_parser1 = nltk.RegexpParser(grammar_np)
sent_tokens1 = nltk.pos_tag(word_tokenize(sentence))

chunk_parser1.parse(sent_tokens1)
# Out:
# Tree('S', [('Barcelona', 'NNP'), ('have', 'VBP'), ('signed', 'VBN'), Tree('NP', [('the', 'DT'), ('highly-rated', 'JJ'), ('teenager', 'NN')]), ('Alen', 'NNP'), ('Halilovic', 'NNP'), ('from', 'IN'), ('Dinamo', 'NNP'), ('Zagreb', 'NNP'), ('on', 'IN'), Tree('NP', [('a', 'DT'), ('five-year', 'JJ'), ('contract', 'NN')])])

# %%
grammar_vp = r"VP: {<VBP|VBN>*<NP|NNP>*<IN>*<NNP>?}"
chunk_parser2 = nltk.RegexpParser(grammar_vp)
sent_tokens2 = nltk.pos_tag(word_tokenize(sentence))

chunk_parser2.parse(sent_tokens2)
# Out:
# Tree('S', [Tree('VP', [('Barcelona', 'NNP')]), Tree('VP', [('have', 'VBP'), ('signed', 'VBN')]), ('the', 'DT'), ('highly-rated', 'JJ'), ('teenager', 'NN'), Tree('VP', [('Alen', 'NNP'), ('Halilovic', 'NNP'), ('from', 'IN'), ('Dinamo', 'NNP')]), Tree('VP', [('Zagreb', 'NNP'), ('on', 'IN')]), ('a', 'DT'), ('five-year', 'JJ'), ('contract', 'NN')])
